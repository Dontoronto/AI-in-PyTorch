# %% [markdown]
# # Human Faces - Explore CeleabA Data in HDF5
#
# Make Your First GAN With PyTorch, 2020

# %%
# mount Drive to access data files

#from google.colab import drive
#drive.mount('./mount')

# %% [markdown]
# ## Explore HDF5 Data

# %%
# import h5py to access data
import h5py

import numpy
import matplotlib.pyplot as plt

# %%
# open HDF5 file and list any groups

with h5py.File('/Volumes/PortableSSD/Projekte/datasets/celeba_dataset/IMG/celeba_aligned_small.h5py', 'r') as file_object:
  
  for group in file_object:
    print(group)
    pass
# Out:
# Volumes

# %%
# open HDF5 file, extract example image as numpy array and plot it

with h5py.File('/Volumes/PortableSSD/Projekte/datasets/celeba_dataset/IMG/celeba_aligned_small.h5py', 'r') as file_object:
  #print(file_object['Volumes']['PortableSSD'])
  #for group in file_object['Volumes']['PortableSSD']['Projekte']['datasets']['celeba_dataset']['IMG']['img_align_celeba']:
  #  print(group)
  dataset = file_object['Volumes']['PortableSSD']['Projekte']['datasets']['celeba_dataset']['IMG']['img_align_celeba']
  image = numpy.array(dataset['6.jpg'])
  plt.imshow(image, interpolation='none')
  pass

# %%
#shape of the image array

image.shape
# Out:
# (218, 178, 3)
